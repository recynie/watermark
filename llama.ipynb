# %%
import subprocess
import os

result = subprocess.run('bash -c "source /etc/network_turbo && env | grep proxy"', shell=True, capture_output=True, text=True)
output = result.stdout
for line in output.splitlines():
    if '=' in line:
        var, value = line.split('=', 1)
        os.environ[var] = value

import os
dir='/root/autodl-tmp/cache/'
os.environ["HF_DATASETS_CACHE"] = dir
os.environ["HF_HOME"] = dir
os.environ["HUGGINGFACE_HUB_CACHE"] = dir
os.environ["TRANSFORMERS_CACHE"] = dir

#!unset http_proxy && unset https_proxy

# %%
import torch
from transformers import pipeline
from toml import load

args=load('config/llama.toml')
TOKEN=args.get('token')
model_id=args['model_id']

pipe = pipeline(
    "text-generation", 
    model=model_id, 
    torch_dtype=torch.bfloat16, 
    device_map="cuda",
    token=TOKEN,
    do_sample=True,
    max_new_tokens=10,
) 
pipe("The key to life is")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[4], line 9
#       6 TOKEN=args.get('token')
#       7 model_id=args['model_id']
# ----> 9 pipe = pipeline(
#      10     "text-generation",
#      11     model=model_id,
#      12     torch_dtype=torch.bfloat16,
#      13     device_map="cuda",
#      14     token=TOKEN,
#      15     do_sample=True,
#      16     max_new_tokens=10,
#      17 )
#      18 pipe("The key to life is")
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/pipelines/__init__.py:940, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     938 if isinstance(model, str) or framework is None:
#     939     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 940     framework, model = infer_framework_load_model(
#     941         model,
#     942         model_classes=model_classes,
#     943         config=config,
#     944         framework=framework,
#     945         task=task,
#     946         **hub_kwargs,
#     947         **model_kwargs,
#     948     )
#     950 model_config = model.config
#     951 hub_kwargs["_commit_hash"] = model.config._commit_hash
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/pipelines/base.py:289, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     283     logger.warning(
#     284         "Model might be a PyTorch model (ending with `.bin`) but PyTorch is not available. "
#     285         "Trying to load the model with Tensorflow."
#     286     )
#     288 try:
# --> 289     model = model_class.from_pretrained(model, **kwargs)
#     290     if hasattr(model, "eval"):
#     291         model = model.eval()
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
#     565         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566     )
#     567 raise ValueError(
#     568     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     570 )
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/modeling_utils.py:4224, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4214         load_contexts.append(tp_device)
#    4216     with ContextManagers(load_contexts):
#    4217         (
#    4218             model,
#    4219             missing_keys,
#    4220             unexpected_keys,
#    4221             mismatched_keys,
#    4222             offload_index,
#    4223             error_msgs,
# -> 4224         ) = cls._load_pretrained_model(
#    4225             model,
#    4226             state_dict,
#    4227             loaded_state_dict_keys,  # XXX: rename?
#    4228             resolved_archive_file,
#    4229             pretrained_model_name_or_path,
#    4230             ignore_mismatched_sizes=ignore_mismatched_sizes,
#    4231             sharded_metadata=sharded_metadata,
#    4232             _fast_init=_fast_init,
#    4233             low_cpu_mem_usage=low_cpu_mem_usage,
#    4234             device_map=device_map,
#    4235             offload_folder=offload_folder,
#    4236             offload_state_dict=offload_state_dict,
#    4237             dtype=torch_dtype,
#    4238             hf_quantizer=hf_quantizer,
#    4239             keep_in_fp32_modules=keep_in_fp32_modules,
#    4240             gguf_path=gguf_path,
#    4241             weights_only=weights_only,
#    4242         )
#    4244 # make sure token embedding weights are still tied if needed
#    4245 model.tie_weights()
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/modeling_utils.py:4794, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_modules, gguf_path, weights_only)
#    4792     else:
#    4793         fixed_state_dict = cls._fix_state_dict_keys_on_load(state_dict)
# -> 4794         new_error_msgs, offload_index, state_dict_index = _load_state_dict_into_meta_model(
#    4795             model_to_load,
#    4796             fixed_state_dict,
#    4797             start_prefix,
#    4798             expected_keys,
#    4799             device_map=device_map,
#    4800             offload_folder=offload_folder,
#    4801             offload_index=offload_index,
#    4802             state_dict_folder=state_dict_folder,
#    4803             state_dict_index=state_dict_index,
#    4804             dtype=dtype,
#    4805             hf_quantizer=hf_quantizer,
#    4806             is_safetensors=is_safetensors,
#    4807             keep_in_fp32_modules=keep_in_fp32_modules,
#    4808             unexpected_keys=unexpected_keys,
#    4809         )
#    4810         error_msgs += new_error_msgs
#    4811 else:
#    4812     # Sharded checkpoint or whole but low_cpu_mem_usage==True
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/modeling_utils.py:873, in _load_state_dict_into_meta_model(model, state_dict, start_prefix, expected_keys, device_map, offload_folder, offload_index, state_dict_folder, state_dict_index, dtype, hf_quantizer, is_safetensors, keep_in_fp32_modules, unexpected_keys, pretrained_model_name_or_path)
#     870         param_device = "cpu" if is_local_dist_rank_0() else "meta"
#     872     # For backward compatibility with older versions of `accelerate` and for non-quantized params
# --> 873     set_module_tensor_to_device(model, param_name, param_device, **set_module_kwargs)
#     874 else:
#     875     hf_quantizer.create_quantized_param(model, param, param_name, param_device, state_dict, unexpected_keys)
#
# File ~/miniconda3/lib/python3.12/site-packages/accelerate/utils/modeling.py:329, in set_module_tensor_to_device(module, tensor_name, device, value, dtype, fp16_statistics, tied_params_map)
#     327             module._parameters[tensor_name] = param_cls(new_value, requires_grad=old_value.requires_grad)
#     328 elif isinstance(value, torch.Tensor):
# --> 329     new_value = value.to(device)
#     330 else:
#     331     new_value = torch.tensor(value, device=device)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 1002.00 MiB. GPU
